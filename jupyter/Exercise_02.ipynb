# %% [markdown]
# # Exercise 02: Classifier Comparison
#
# In this exercise, you'll run several classifiers on the same data and compare their effectiveness.

# %% [markdown]
# ## Installing Modules

# %%
import sys
# !{sys.executable} -m pip install -U pip
# !{sys.executable} -m pip install -U scikit-learn matplotlib seaborn pandas
# Out:
# Requirement already satisfied: pip in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (24.0)
# Requirement already satisfied: scikit-learn in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: matplotlib in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (3.8.2)
# Collecting matplotlib
#   Downloading matplotlib-3.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: seaborn in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: pandas in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in /home/karan/.pyenv/versions/3.10.13/envs/my_dir_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 87.0 MB/s eta 0:00:000m eta 0:00:010:00:01
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.2
#     Uninstalling matplotlib-3.8.2:
#       Successfully uninstalled matplotlib-3.8.2
# Successfully installed matplotlib-3.8.3

# %% [markdown]
# ## Setup

# %% [markdown]
# Load the pre-canned wine dataset:

# %%
from sklearn import datasets
dataset = datasets.load_wine()

# %% [markdown]
# Split test data into training/testing sets:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    dataset['data'], dataset['target'], test_size=0.4, random_state=10
)

# %% [markdown]
# ## K Nearest Neighbors
#
# Spend a little time learning about K Nearest Neighbor (KNN) classifiers.
#
# Once you have a handle on how they work, run the code below and inspect the results.

# %%
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

clf = KNeighborsClassifier(3)
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)

print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
print(f"Confusion matrix:\n{disp.confusion_matrix}")
disp.figure_.suptitle("K Nearest Neighbors Confusion Matrix")
plt.show()
# Out:
# Classification report for classifier KNeighborsClassifier(n_neighbors=3):
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77        20
#            1       0.87      0.61      0.71        33
#            2       0.52      0.68      0.59        19
#
#     accuracy                           0.69        72
#    macro avg       0.70      0.71      0.69        72
# weighted avg       0.73      0.69      0.70        72
#
#
# Confusion matrix:
# [[17  0  3]
#  [ 4 20  9]
#  [ 3  3 13]]

# %% [markdown]
# ## Support Vector Machines
#
# Spend a little time learning about support vector machine (SVM) classifiers.
#
# I've copied the KNN code from above to get you started...modify it to run a support vector machine classifier, and inspect the results.

# %%
##
## UPDATE THIS CODE
##

import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

clf = KNeighborsClassifier(3)
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)

print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
print(f"Confusion matrix:\n{disp.confusion_matrix}")
disp.figure_.suptitle("K Nearest Neighbors Confusion Matrix")
plt.show()
# Out:
# Classification report for classifier KNeighborsClassifier(n_neighbors=3):
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77        20
#            1       0.87      0.61      0.71        33
#            2       0.52      0.68      0.59        19
#
#     accuracy                           0.69        72
#    macro avg       0.70      0.71      0.69        72
# weighted avg       0.73      0.69      0.70        72
#
#
# Confusion matrix:
# [[17  0  3]
#  [ 4 20  9]
#  [ 3  3 13]]

# %% [markdown]
# ## Decision Trees
#
# Spend a little time learning about decision tree classifiers.
#
# I've copied the KNN code from above to get you started...modify it to run a decision tree classifier, and inspect the results.

# %%
##
## UPDATE THIS CODE
##

import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics, svm

#clf = KNeighborsClassifier(3)
clf = svm.SVC()
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)

print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
print(f"Confusion matrix:\n{disp.confusion_matrix}")
disp.figure_.suptitle("SVM Confusion Matrix")
plt.show()
# Out:
# Classification report for classifier SVC():
#               precision    recall  f1-score   support
#
#            0       0.82      0.70      0.76        20
#            1       0.73      0.67      0.70        33
#            2       0.40      0.53      0.45        19
#
#     accuracy                           0.64        72
#    macro avg       0.65      0.63      0.64        72
# weighted avg       0.67      0.64      0.65        72
#
#
# Confusion matrix:
# [[14  0  6]
#  [ 2 22  9]
#  [ 1  8 10]]

# %% [markdown]
# ## Random Forest Classifiers
#
# Spend a little time learning about random forest classifiers.
#
# I've copied the KNN code from above to get you started...modify it to run a random forest classifier, and inspect the results.

# %%
##
## UPDATE THIS CODE
##

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

#clf = KNeighborsClassifier(3)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)

print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_test, predicted)}\n"
)

disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, predicted)
print(f"Confusion matrix:\n{disp.confusion_matrix}")
disp.figure_.suptitle("RFC Confusion Matrix")
plt.show()
# Out:
# Classification report for classifier RandomForestClassifier():
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      0.94      0.97        33
#            2       0.90      1.00      0.95        19
#
#     accuracy                           0.97        72
#    macro avg       0.97      0.98      0.97        72
# weighted avg       0.97      0.97      0.97        72
#
#
# Confusion matrix:
# [[20  0  0]
#  [ 0 31  2]
#  [ 0  0 19]]

# %% [markdown]
# ## Questions

# %% [markdown]
# Compare and contrast the performance of the classifiers. Which do you think is best, and which worst? Are there any patterns? Anything else interesting to report?

# %% [markdown]
# I think KNN is the best since it is the most simple to use, however, the quality of the model downgrades once theres more dataset variation and variability.

# %% [markdown]
# Was there a pattern to the changes you needed to make?  What does that say about the design of the `scikit-learn` estimators and APIs?

# %% [markdown]
# Yes, all I did was import the proper library and then change 1-2 function calls to call from that classifier. It shows that you can create models with very little chanhes in code and makes it easier to compare and contrast data amongst different models.

# %% [markdown]
# ## Follow-up
#
# Go back to the train/test split step, and change the `random_state` value.  Rerun the classifiers and inspect the results.  Do this several times for several `random_state` values.  What do you observe?

# %% [markdown]
# The subset of data was changed.

# %% [markdown]
# What does this imply about the training process?

# %% [markdown]
# It implies that results can be almost saved during training by saving the seed number (random_state)

# %% [markdown]
# What is `random_state` doing?

# %% [markdown]
# It is used to seed the random number generator and create a similar repetition for certain outputs

# %% [markdown]
# What should you do to ensure your ML results are reproducible?

# %% [markdown]
# Use a fixed random_state

# %% [markdown]
# **MAKE SURE YOU SAVE, COMMIT, AND PUSH YOUR NOTEBOOKS TO YOUR REPO!!**
